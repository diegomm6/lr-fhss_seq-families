# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # FHSLocator predecode receiver

# %% [markdown]
# ## driver cr1

# %%
data = pd.read_csv('fhslreceiver/cr1-8to31frg-20ns.csv', index_col=0, header=None).T
nodes = data['nodes'].to_numpy()

fhslocator_results = np.add(data['driver-tp'].to_numpy(), data['driver-fp'].to_numpy())
decoded_decodable = np.add(data['driver-decoded_hrd_pld'].to_numpy(), data['driver-decodable_pld'].to_numpy())
decodable_collided = np.add(data['driver-decodable_pld'].to_numpy(), data['driver-collided_hdr_pld'].to_numpy())

plt.figure(figsize=(10,10))

plt.plot(nodes, data['driver-decoded_hrd_pld'], label=f'decoded_hrd_pld (n1)')
plt.plot(nodes, data['driver-decoded_hdr'], label=f'decoded_hdr (n2)')
plt.plot(nodes, data['driver-decodable_pld'], label=f'decodable_pld (n3)')
plt.plot(nodes, data['driver-collided_hdr_pld'], label=f'collided_hdr_pld (n4)')

plt.plot(nodes, nodes, label=f'total txs (N)', color='k', linestyle='dotted')

plt.title('LR-FHSS Decoder results')
plt.xlabel('nodes')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('count')
plt.xlim(1e1,1e3)
#plt.ylim(0,1.1e2)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,4))

plt.plot(nodes, fhslocator_results, label=f'tp + fp (Ĉ)', color='r', linestyle='dashed')
plt.plot(nodes, data['driver-tp'], label=f'tp')
plt.plot(nodes, data['driver-fp'], label=f'fp')
plt.plot(nodes, data['driver-fn'], label=f'fn')
plt.plot(nodes, decodable_collided, label=f'collided hdrs (C)', color='k', linestyle='dotted')

#plt.axvline(x=lim, color='m', label=f'limit={lim}')

plt.title('FHS Locator results')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.yscale('log')
plt.xlim(1e1,1e3)
#plt.ylim(0,1e3)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(nodes, data['driver-chocc'], label='channel occupancy [%]')
plt.plot(nodes, np.divide(decoded_decodable, nodes), label='decodable pld rate = (n1+n3)/N')
plt.plot(nodes, np.divide(decodable_collided, fhslocator_results), label='C / Ĉ = (n3+n4)/(tp+fp)')

plt.title('OCW channel occuapncy')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('rate')
plt.xlim(1e1,1e3)
plt.grid()
plt.legend()
plt.show()
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_15908\1321133011.py:5: RuntimeWarning: invalid value encountered in divide
#   plt.plot(nodes, np.divide(decodable_collided, fhslocator_results), label='C / Ĉ = (n3+n4)/(tp+fp)')

# %%
plt.figure(figsize=(10,5))

plt.plot(nodes, data['driver-time'], label='time')

plt.title('FHS Locator time')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('time')
#plt.xlim(1e2,5e2)
#plt.ylim(1.2e2,1.4e2)
plt.grid()
#plt.legend()
plt.show()

# %% [markdown]
# ## lifan cr1

# %%
fhslocator_results = np.add(data['lifan-tp'].to_numpy(), data['lifan-fp'].to_numpy())
decoded_decodable = np.add(data['lifan-decoded_hrd_pld'].to_numpy(), data['lifan-decodable_pld'].to_numpy())
decodable_collided = np.add(data['lifan-decodable_pld'].to_numpy(), data['lifan-collided_hdr_pld'].to_numpy())

plt.figure(figsize=(10,10))

plt.plot(nodes, data['lifan-decoded_hrd_pld'], label=f'decoded_hrd_pld (n1)')
plt.plot(nodes, data['lifan-decoded_hdr'], label=f'decoded_hdr (n2)')
plt.plot(nodes, data['lifan-decodable_pld'], label=f'decodable_pld (n3)')
plt.plot(nodes, data['lifan-collided_hdr_pld'], label=f'collided_hdr_pld (n4)')

plt.plot(nodes, nodes, label=f'total txs (N)', color='k', linestyle='dotted')

plt.title('LR-FHSS Decoder results')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.xlim(1e1,1e3)
plt.ylim(0,1.1e2)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,4))

plt.plot(nodes, fhslocator_results, label=f'tp + fp (Ĉ)', color='r', linestyle='dashed')
plt.plot(nodes, data['lifan-tp'], label=f'tp')
plt.plot(nodes, data['lifan-fp'], label=f'fp')
plt.plot(nodes, data['lifan-fn'], label=f'fn')
plt.plot(nodes, decodable_collided, label=f'collided hdrs (C)', color='k', linestyle='dotted')

plt.title('FHS Locator results')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.xlim(1e1,1e3)
plt.ylim(0,1e3)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(nodes, data['lifan-chocc'], label='channel occupancy [%]')
plt.plot(nodes, np.divide(decoded_decodable, nodes), label='decodable pld rate = (n1+n3)/N')
plt.plot(nodes, np.divide(decodable_collided, fhslocator_results), label='C / Ĉ = (n3+n4)/(tp+fp)')

plt.title('OCW channel occuapncy')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('rate')
plt.xlim(1e1,1e3)
plt.grid()
plt.legend()
plt.show()
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_15908\2114395644.py:5: RuntimeWarning: invalid value encountered in divide
#   plt.plot(nodes, np.divide(decodable_collided, fhslocator_results), label='C / Ĉ = (n3+n4)/(tp+fp)')

# %%
plt.figure(figsize=(10,5))

plt.plot(nodes, data['lifan-time'], label='time')

plt.title('FHS Locator time')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('time s')
#plt.xlim(1e2,5e2)
#plt.ylim(1e1,1.4e1)
plt.grid()
#plt.legend()
plt.show()

# %% [markdown]
# ## driver cr2

# %%
data = pd.read_csv('fhslreceiver/cr2-8to31frg-40ns.csv', index_col=0, header=None).T
nodes = data['nodes'].to_numpy()

fhslocator_results = np.add(data['driver-tp'].to_numpy(), data['driver-fp'].to_numpy())
decoded_decodable = np.add(data['driver-decoded_hrd_pld'].to_numpy(), data['driver-decodable_pld'].to_numpy())
decodable_collided = np.add(data['driver-decodable_pld'].to_numpy(), data['driver-collided_hdr_pld'].to_numpy())

plt.figure(figsize=(10,10))

plt.plot(nodes, data['driver-decoded_hrd_pld'], label=f'decoded_hrd_pld (n1)')
plt.plot(nodes, data['driver-decoded_hdr'], label=f'decoded_hdr (n2)')
plt.plot(nodes, data['driver-decodable_pld'], label=f'decodable_pld (n3)')
plt.plot(nodes, data['driver-collided_hdr_pld'], label=f'collided_hdr_pld (n4)')

plt.plot(nodes, nodes, label=f'total txs (N)', color='k', linestyle='dotted')

plt.title('LR-FHSS Decoder results')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.xlim(1e1,1e3)
plt.ylim(0,1.1e2)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,4))

plt.plot(nodes, fhslocator_results, label=f'tp + fp (Ĉ)', color='r', linestyle='dashed')
plt.plot(nodes, data['driver-tp'], label=f'tp')
plt.plot(nodes, data['driver-fp'], label=f'fp')
plt.plot(nodes, data['driver-fn'], label=f'fn')
plt.plot(nodes, decodable_collided, label=f'collided hdrs (C)', color='k', linestyle='dotted')

#plt.axvline(x=lim, color='m', label=f'limit={lim}')

plt.title('FHS Locator results')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.xlim(1e1,1e3)
plt.ylim(0,1e3)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(nodes, data['driver-chocc'], label='channel occupancy [%]')
plt.plot(nodes, np.divide(decoded_decodable, nodes), label='decodable pld rate = (n1+n3)/N')
plt.plot(nodes, np.divide(decodable_collided, fhslocator_results), label='C / Ĉ = (n3+n4)/(tp+fp)')

plt.title('OCW channel occuapncy')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('rate')
plt.xlim(1e1,1e3)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## lifan cr2

# %%
data = pd.read_csv('fhslreceiver/cr2-8to31frg-40ns.csv', index_col=0, header=None).T
nodes = data['nodes'].to_numpy()

fhslocator_results = np.add(data['lifan-tp'].to_numpy(), data['lifan-fp'].to_numpy())
decoded_decodable = np.add(data['lifan-decoded_hrd_pld'].to_numpy(), data['lifan-decodable_pld'].to_numpy())
decodable_collided = np.add(data['lifan-decodable_pld'].to_numpy(), data['lifan-collided_hdr_pld'].to_numpy())

plt.figure(figsize=(10,10))

plt.plot(nodes, data['lifan-decoded_hrd_pld'], label=f'decoded_hrd_pld (n1)')
plt.plot(nodes, data['lifan-decoded_hdr'], label=f'decoded_hdr (n2)')
plt.plot(nodes, data['lifan-decodable_pld'], label=f'decodable_pld (n3)')
plt.plot(nodes, data['lifan-collided_hdr_pld'], label=f'collided_hdr_pld (n4)')

plt.plot(nodes, nodes, label=f'total txs (N)', color='k', linestyle='dotted')

plt.title('LR-FHSS Decoder results')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.xlim(1e1,1e3)
plt.ylim(0,1.1e2)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,4))

plt.plot(nodes, fhslocator_results, label=f'tp + fp (Ĉ)', color='r', linestyle='dashed')
plt.plot(nodes, data['lifan-tp'], label=f'tp')
plt.plot(nodes, data['lifan-fp'], label=f'fp')
plt.plot(nodes, data['lifan-fn'], label=f'fn')
plt.plot(nodes, decodable_collided, label=f'collided hdrs (C)', color='k', linestyle='dotted')

plt.title('FHS Locator results')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.xlim(1e1,1e3)
plt.ylim(0,1e3)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(nodes, data['lifan-chocc'], label='channel occupancy [%]')
plt.plot(nodes, np.divide(decoded_decodable, nodes), label='decodable pld rate = (n1+n3)/N')
plt.plot(nodes, np.divide(decodable_collided, fhslocator_results), label='C / Ĉ = (n3+n4)/(tp+fp)')

plt.title('OCW channel occuapncy')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('rate')
plt.xlim(1e1,1e3)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # 31 frgs

# %% [markdown]
# ## driver

# %%
data = pd.read_csv('fhslreceiver/cr1-31frg-40ns.csv', index_col=0, header=None).T
nodes = data['nodes'].to_numpy()

fhslocator_results = np.add(data['driver-tp'].to_numpy(), data['driver-fp'].to_numpy())
decoded_decodable = np.add(data['driver-decoded_hrd_pld'].to_numpy(), data['driver-decodable_pld'].to_numpy())
decodable_collided = np.add(data['driver-decodable_pld'].to_numpy(), data['driver-collided_hdr_pld'].to_numpy())

plt.figure(figsize=(10,10))

plt.plot(nodes, data['driver-decoded_hrd_pld'], label=f'decoded_hrd_pld')
plt.plot(nodes, data['driver-decoded_hdr'], label=f'decoded_hdr')
plt.plot(nodes, data['driver-decodable_pld'], label=f'decodable_pld')
plt.plot(nodes, data['driver-collided_hdr_pld'], label=f'collided_hdr_pld')

plt.plot(nodes, nodes, label=f'x=y', color='k', linestyle='dotted')

plt.title('cr1, driver, 31 fragments, 10 runs')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.xlim(1e1,1e3)
plt.ylim(0,1.1e2)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(nodes, fhslocator_results, label=f'tp+fp', color='r', linestyle='dashed')
plt.plot(nodes, data['driver-tp'], label=f'tp')
plt.plot(nodes, data['driver-fp'], label=f'fp')
plt.plot(nodes, data['driver-fn'], label=f'fn')
plt.plot(nodes, decodable_collided, label=f'nCollided', color='k', linestyle='dotted')

#plt.axvline(x=lim, color='m', label=f'limit={lim}')

plt.title('FHS Locator results')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.yscale('log')
plt.xlim(1e1,1e3)
#plt.ylim(0,1e3)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(nodes, data['driver-chocc'], label='channel occupancy')
plt.plot(nodes, np.divide(decoded_decodable, nodes), label='decodable payloads')
plt.plot(nodes, np.divide(decodable_collided, fhslocator_results), label='nCollided/estnCollided')

plt.title('cr1, driver, 31 fragments, 10 runs')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('ch occupancy')
plt.xlim(1e1,1e3)
plt.grid()
plt.legend()
plt.show()
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_15908\4065878398.py:5: RuntimeWarning: invalid value encountered in divide
#   plt.plot(nodes, np.divide(decodable_collided, fhslocator_results), label='nCollided/estnCollided')

# %% [markdown]
# ## lifan

# %%
fhslocator_results = np.add(data['lifan-tp'].to_numpy(), data['lifan-fp'].to_numpy())
decoded_decodable = np.add(data['lifan-decoded_hrd_pld'].to_numpy(), data['lifan-decodable_pld'].to_numpy())
decodable_collided = np.add(data['lifan-decodable_pld'].to_numpy(), data['lifan-collided_hdr_pld'].to_numpy())

plt.figure(figsize=(10,10))

plt.plot(nodes, data['lifan-decoded_hrd_pld'], label=f'decoded_hrd_pld')
plt.plot(nodes, data['lifan-decoded_hdr'], label=f'decoded_hdr')
plt.plot(nodes, data['lifan-decodable_pld'], label=f'decodable_pld')
plt.plot(nodes, data['lifan-collided_hdr_pld'], label=f'collided_hdr_pld')

plt.plot(nodes, nodes, label=f'x=y', color='k', linestyle='dotted')

plt.title('cr1, lifan, 31 fragments, 10 runs')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.xlim(1e1,1e3)
plt.ylim(0,1.1e2)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(nodes, fhslocator_results, label=f'tp+fp', color='r', linestyle='dashed')
plt.plot(nodes, data['lifan-tp'], label=f'tp')
plt.plot(nodes, data['lifan-fp'], label=f'fp')
plt.plot(nodes, data['lifan-fn'], label=f'fn')
plt.plot(nodes, decodable_collided, label=f'nCollided', color='k', linestyle='dotted')

plt.title('cr1, lifan, 31 fragments, 10 runs')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.yscale('log')
plt.xlim(1e1,1e3)
#plt.ylim(0,1e3)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(nodes, data['lifan-chocc'], label='channel occupancy')
plt.plot(nodes, np.divide(decoded_decodable, nodes), label='decodable payloads')
plt.plot(nodes, np.divide(decodable_collided, fhslocator_results), label='nCollided/estnCollided')

plt.title('cr1, lifan, 31 fragments, 10 runs')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('ch occupancy')
plt.grid()
plt.legend()
plt.show()
