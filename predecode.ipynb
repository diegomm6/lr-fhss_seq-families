# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # FHSLocator predecode receiver

# %% [markdown]
# ## driver cr1

# %%
data = pd.read_csv('fhslreceiver/predecode.csv', index_col=0, header=None).T
nodes = data['nodes'].to_numpy()

fhslocator_results = np.add(data['nodrop-cr1-500p-tp'].to_numpy(), data['nodrop-cr1-500p-fp'].to_numpy())
decoded_decodable = np.add(data['nodrop-cr1-500p-decoded_hrd_pld'].to_numpy(), data['nodrop-cr1-500p-decodable_pld'].to_numpy())
decodable_collided = np.add(data['nodrop-cr1-500p-decodable_pld'].to_numpy(), data['nodrop-cr1-500p-collided_hdr_pld'].to_numpy())

plt.figure(figsize=(10,10))

plt.plot(nodes, data['nodrop-cr1-500p-decoded_hrd_pld'], label=f'decoded_hrd_pld')
plt.plot(nodes, data['nodrop-cr1-500p-decoded_hdr'], label=f'decoded_hdr')
plt.plot(nodes, data['nodrop-cr1-500p-decodable_pld'], label=f'decodable_pld')
plt.plot(nodes, data['nodrop-cr1-500p-collided_hdr_pld'], label=f'collided_hdr_pld')

plt.plot(nodes, nodes, label=f'x=y', color='k', linestyle='dotted')

plt.title('cr1, driver, 8-30 fragments')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.xlim(1e1,1e3)
plt.ylim(0,1.5e2)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(nodes, fhslocator_results, label=f'tp+fp', color='r', linestyle='dashed')
plt.plot(nodes, data['nodrop-cr1-500p-tp'], label=f'tp')
plt.plot(nodes, data['nodrop-cr1-500p-fp'], label=f'fp')
plt.plot(nodes, data['nodrop-cr1-500p-fn'], label=f'fn')
plt.plot(nodes, decodable_collided, label=f'nCollided', color='k', linestyle='dotted')

#plt.axvline(x=lim, color='m', label=f'limit={lim}')

plt.title('cr1, 8-30 fragments, 10 runs')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.xlim(1e1,1e3)
plt.ylim(0,1e3)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(nodes, data['nodrop-cr1-500p-chocc'], label='channel occupancy')
plt.plot(nodes, np.divide(decoded_decodable, nodes), label='decodable payloads')
plt.plot(nodes, np.divide(decodable_collided, fhslocator_results), label='nCollided/estnCollided')

plt.title('cr1, 8-30 fragments, 10 runs')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('ch occupancy')
plt.grid()
plt.legend()
plt.show()
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_4688\2851939734.py:5: RuntimeWarning: invalid value encountered in divide
#   plt.plot(nodes, np.divide(decodable_collided, fhslocator_results), label='nCollided/estnCollided')

# %% [markdown]
# ## lifan cr1

# %%
data = pd.read_csv('fhslreceiver/predecode.csv', index_col=0, header=None).T
nodes = data['nodes'].to_numpy()

fhslocator_results = np.add(data['nodrop-lifan-cr1-500p-tp'].to_numpy(), data['nodrop-lifan-cr1-500p-fp'].to_numpy())
decoded_decodable = np.add(data['nodrop-lifan-cr1-500p-decoded_hrd_pld'].to_numpy(), data['nodrop-lifan-cr1-500p-decodable_pld'].to_numpy())
decodable_collided = np.add(data['nodrop-lifan-cr1-500p-decodable_pld'].to_numpy(), data['nodrop-lifan-cr1-500p-collided_hdr_pld'].to_numpy())

plt.figure(figsize=(10,10))

plt.plot(nodes, data['nodrop-lifan-cr1-500p-decoded_hrd_pld'], label=f'decoded_hrd_pld')
plt.plot(nodes, data['nodrop-lifan-cr1-500p-decoded_hdr'], label=f'decoded_hdr')
plt.plot(nodes, data['nodrop-lifan-cr1-500p-decodable_pld'], label=f'decodable_pld')
plt.plot(nodes, data['nodrop-lifan-cr1-500p-collided_hdr_pld'], label=f'collided_hdr_pld')

plt.plot(nodes, nodes, label=f'x=y', color='k', linestyle='dotted')

plt.title('cr1, driver, 8-30 fragments')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.xlim(1e1,1e3)
plt.ylim(0,1.5e2)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(nodes, fhslocator_results, label=f'tp+fp', color='r', linestyle='dashed')
plt.plot(nodes, data['nodrop-lifan-cr1-500p-tp'], label=f'tp')
plt.plot(nodes, data['nodrop-lifan-cr1-500p-fp'], label=f'fp')
plt.plot(nodes, data['nodrop-lifan-cr1-500p-fn'], label=f'fn')
plt.plot(nodes, decodable_collided, label=f'nCollided', color='k', linestyle='dotted')

plt.title('cr1, 8-30 fragments, 10 runs')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.xlim(1e1,1e3)
plt.ylim(0,1e3)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(nodes, data['nodrop-lifan-cr1-500p-chocc'], label='channel occupancy')
plt.plot(nodes, np.divide(decoded_decodable, nodes), label='decodable payloads')
plt.plot(nodes, np.divide(decodable_collided, fhslocator_results), label='nCollided/estnCollided')

plt.title('cr1, 8-30 fragments, 10 runs')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('ch occupancy')
plt.grid()
plt.legend()
plt.show()
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_4688\3885898502.py:5: RuntimeWarning: invalid value encountered in divide
#   plt.plot(nodes, np.divide(decodable_collided, fhslocator_results), label='nCollided/estnCollided')

# %% [markdown]
# # 31 frgs

# %% [markdown]
# ## driver

# %%
data = pd.read_csv('fhslreceiver/lifan31frgs.csv', index_col=0, header=None).T
nodes = data['nodes'].to_numpy()

fhslocator_results = np.add(data['cr1-800p-31frg-tp'].to_numpy(), data['cr1-800p-31frg-fp'].to_numpy())
decoded_decodable = np.add(data['cr1-800p-31frg-decoded_hrd_pld'].to_numpy(), data['cr1-800p-31frg-decodable_pld'].to_numpy())
decodable_collided = np.add(data['cr1-800p-31frg-decodable_pld'].to_numpy(), data['cr1-800p-31frg-collided_hdr_pld'].to_numpy())

plt.figure(figsize=(10,10))

plt.plot(nodes, data['cr1-800p-31frg-decoded_hrd_pld'], label=f'decoded_hrd_pld')
plt.plot(nodes, data['cr1-800p-31frg-decoded_hdr'], label=f'decoded_hdr')
plt.plot(nodes, data['cr1-800p-31frg-decodable_pld'], label=f'decodable_pld')
plt.plot(nodes, data['cr1-800p-31frg-collided_hdr_pld'], label=f'collided_hdr_pld')

plt.plot(nodes, nodes, label=f'x=y', color='k', linestyle='dotted')

plt.title('cr1, driver, 8-30 fragments')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.xlim(1e1,1e3)
plt.ylim(0,1.5e2)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(nodes, fhslocator_results, label=f'tp+fp', color='r', linestyle='dashed')
plt.plot(nodes, data['cr1-800p-31frg-tp'], label=f'tp')
plt.plot(nodes, data['cr1-800p-31frg-fp'], label=f'fp')
plt.plot(nodes, data['cr1-800p-31frg-fn'], label=f'fn')
plt.plot(nodes, decodable_collided, label=f'nCollided', color='k', linestyle='dotted')

#plt.axvline(x=lim, color='m', label=f'limit={lim}')

plt.title('cr1, 8-30 fragments, 10 runs')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.xlim(1e1,1e3)
plt.ylim(0,1e3)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(nodes, data['cr1-800p-31frg-chocc'], label='channel occupancy')
plt.plot(nodes, np.divide(decoded_decodable, nodes), label='decodable payloads')
plt.plot(nodes, np.divide(decodable_collided, fhslocator_results), label='nCollided/estnCollided')

plt.title('cr1, 8-30 fragments, 10 runs')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('ch occupancy')
plt.grid()
plt.legend()
plt.show()
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_4688\2120052396.py:5: RuntimeWarning: invalid value encountered in divide
#   plt.plot(nodes, np.divide(decodable_collided, fhslocator_results), label='nCollided/estnCollided')

# %% [markdown]
# ## lifan

# %%
fhslocator_results = np.add(data['lifan-cr1-800p-31frg-tp'].to_numpy(), data['lifan-cr1-800p-31frg-fp'].to_numpy())
decoded_decodable = np.add(data['lifan-cr1-800p-31frg-decoded_hrd_pld'].to_numpy(), data['lifan-cr1-800p-31frg-decodable_pld'].to_numpy())
decodable_collided = np.add(data['lifan-cr1-800p-31frg-decodable_pld'].to_numpy(), data['lifan-cr1-800p-31frg-collided_hdr_pld'].to_numpy())

plt.figure(figsize=(10,10))

plt.plot(nodes, data['lifan-cr1-800p-31frg-decoded_hrd_pld'], label=f'decoded_hrd_pld')
plt.plot(nodes, data['lifan-cr1-800p-31frg-decoded_hdr'], label=f'decoded_hdr')
plt.plot(nodes, data['lifan-cr1-800p-31frg-decodable_pld'], label=f'decodable_pld')
plt.plot(nodes, data['lifan-cr1-800p-31frg-collided_hdr_pld'], label=f'collided_hdr_pld')

plt.plot(nodes, nodes, label=f'x=y', color='k', linestyle='dotted')

plt.title('cr1, driver, 8-30 fragments')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.xlim(1e1,1e3)
plt.ylim(0,1.5e2)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(nodes, fhslocator_results, label=f'tp+fp', color='r', linestyle='dashed')
plt.plot(nodes, data['lifan-cr1-800p-31frg-tp'], label=f'tp')
plt.plot(nodes, data['lifan-cr1-800p-31frg-fp'], label=f'fp')
plt.plot(nodes, data['lifan-cr1-800p-31frg-fn'], label=f'fn')
plt.plot(nodes, decodable_collided, label=f'nCollided', color='k', linestyle='dotted')

plt.title('cr1, 8-30 fragments, 10 runs')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('count')
plt.xlim(1e1,1e3)
plt.ylim(0,1e3)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(nodes, data['lifan-cr1-800p-31frg-chocc'], label='channel occupancy')
plt.plot(nodes, np.divide(decoded_decodable, nodes), label='decodable payloads')
plt.plot(nodes, np.divide(decodable_collided, fhslocator_results), label='nCollided/estnCollided')

plt.title('cr1, 8-30 fragments, 10 runs')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('ch occupancy')
plt.grid()
plt.legend()
plt.show()
