# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ---
# # packet level collisions CR2 duty cycle 25%

# %%
data25DC = pd.read_csv('NEWresults/data-25DC-CR2.csv', index_col=0, header=None).T
nodes = data25DC['nodes'].to_numpy()

lifan_CR2_infp_dec_pckts = np.subtract(nodes, data25DC['lifan-CR2-infp-col_pckts'].to_numpy())
driver_CR2_infp_dec_pckts = np.subtract(nodes, data25DC['driver-CR2-infp-col_pckts'].to_numpy())
lemgreen_CR2_infp_dec_pckts = np.subtract(nodes, np.multiply(nodes, data25DC['lemgreen-CR2-infp-col_pckts'].to_numpy()))

plt.figure(figsize=(8,8))

#plt.plot(nodes, lifan_CR2_infp_dec_pckts, label=f'li-fan CR2 infp', color='#d62728')
plt.plot(nodes, lemgreen_CR2_infp_dec_pckts, label=f'lem-green CR2 infp', color='#d62728')
plt.plot(nodes, driver_CR2_infp_dec_pckts, label=f'driver CR2 infp', color='#d62728', linestyle='dashed')

#plt.plot(nodes, data25DC['lifan-CR2-100p-dec_pckts'], label=f'li-fan CR2 100p early d/d', color='#1f77b4', marker='$I$')
plt.plot(nodes, data25DC['lemgreen-CR2-100p-dec_pckts'], label=f'lem-green CR2 100p early d/d', color='#1f77b4', marker='$I$')
plt.plot(nodes, data25DC['driver-CR2-100p-dec_pckts'], label=f'driver CR2 100p early d/d', color='#1f77b4', marker='$I$', linestyle='dotted')

#plt.plot(nodes, data25DC['lifan-CR2-100p-dec_pckts-base'], label=f'li-fan CR2 100p base', color='#ff7f0e')
plt.plot(nodes, data25DC['lemgreen-CR2-100p-dec_pckts-base'], label=f'lem-green CR2 100p base', color='#ff7f0e')
plt.plot(nodes, data25DC['driver-CR2-100p-dec_pckts-base'], label=f'driver CR2 100p base', color='#ff7f0e', linestyle='dashed')

#plt.plot(nodes, data25DC['lifan-CR2-1000p-dec_pckts'], label=f'li-fan CR2 1000p early d/d', color='#9467bd', marker='$I$')
plt.plot(nodes, data25DC['lemgreen-CR2-1000p-dec_pckts'], label=f'lem-green CR2 1000p early d/d', color='#9467bd', marker='$I$')
plt.plot(nodes, data25DC['driver-CR2-1000p-dec_pckts'], label=f'driver CR2 1000p early d/d', color='#9467bd', marker='$I$', linestyle='dotted')

#plt.plot(nodes, data25DC['lifan-CR2-1000p-dec_pckts-base'], label=f'li-fan CR2 1000p base', color='#2ca02c')
plt.plot(nodes, data25DC['lemgreen-CR2-1000p-dec_pckts-base'], label=f'lem-green CR2 1000p base', color='#2ca02c')
plt.plot(nodes, data25DC['driver-CR2-1000p-dec_pckts-base'], label=f'driver CR2 1000p base', color='#2ca02c', linestyle='dashed')


plt.title('total decoded packets')
plt.xlabel('sent packets')
plt.xscale('log')
plt.ylabel('decoded packets')
plt.xlim(1e2,1e4)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,8))

#plt.plot(nodes, data25DC['lifan-CR2-infp-col_pckts'], label=f'li-fan CR2 infp', color='#d62728')
#plt.plot(nodes, data25DC['driver-CR2-infp-col_pckts'], label=f'driver CR2 infp', color='#d62728', linestyle='dashed')

plt.plot(nodes, data25DC['lifan-CR2-100p-col_pckts'], label=f'li-fan CR2 100p early d/d', color='#1f77b4')
plt.plot(nodes, data25DC['driver-CR2-100p-col_pckts'], label=f'driver CR2 100p early d/d', color='#1f77b4', linestyle='dashdot')

plt.plot(nodes, data25DC['lifan-CR2-100p-col_pckts-base'], label=f'li-fan CR2 100p base', color='#ff7f0e')
plt.plot(nodes, data25DC['driver-CR2-100p-col_pckts-base'], label=f'driver CR2 100p base', color='#ff7f0e', linestyle='dashed')

plt.plot(nodes, data25DC['lifan-CR2-1000p-col_pckts'], label=f'li-fan CR2 1000p early d/d', color='#9467bd')
plt.plot(nodes, data25DC['driver-CR2-1000p-col_pckts'], label=f'driver CR2 1000p early d/d', color='#9467bd', linestyle='dashed')

plt.plot(nodes, data25DC['lifan-CR2-1000p-col_pckts-base'], label=f'li-fan CR2 1000p base', color='#2ca02c')
plt.plot(nodes, data25DC['driver-CR2-1000p-col_pckts-base'], label=f'driver CR2 1000p base', color='#2ca02c', linestyle='dashed')


plt.title('total colided packets')
plt.xlabel('nodes')
#plt.xscale('log')
plt.ylabel('colided packets')
#plt.xlim(1e2,1e4)
#plt.ylim(0,1e3)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# plt.figure(figsize=(8,8))
#
# plt.plot(nodes, np.divide(lifan_CR2_infp_dec_pckts,nodes), label=f'li-fan CR2 infp', color='#d62728')
# plt.plot(nodes, np.divide(driver_CR2_infp_dec_pckts,nodes), label=f'driver CR2 infp', color='#d62728', linestyle='dashed')
#
# plt.plot(nodes, np.divide(data25DC['lifan-CR2-100p-dec_pckts'],nodes), label=f'li-fan CR2 100p early d/d', color='#1f77b4')
# plt.plot(nodes, np.divide(data25DC['driver-CR2-100p-dec_pckts'],nodes), label=f'driver CR2 100p early d/d', color='#1f77b4', linestyle='dashed')
#
# plt.plot(nodes, np.divide(data25DC['lifan-CR2-100p-dec_pckts-base'],nodes), label=f'li-fan CR2 100p base', color='#ff7f0e')
# plt.plot(nodes, np.divide(data25DC['driver-CR2-100p-dec_pckts-base'],nodes), label=f'driver CR2 100p base', color='#ff7f0e', linestyle='dashed')
#
# plt.plot(nodes, np.divide(data25DC['lifan-CR2-1000p-dec_pckts'],nodes), label=f'li-fan CR2 1kp early d/d', color='#9467bd')
# plt.plot(nodes, np.divide(data25DC['driver-CR2-1000p-dec_pckts'],nodes), label=f'driver CR2 1kp early d/d', color='#9467bd', linestyle='dashed')
#
# plt.plot(nodes, np.divide(data25DC['lifan-CR2-1000p-dec_pckts-base'],nodes), label=f'li-fan CR2 1kp base', color='#2ca02c')
# plt.plot(nodes, np.divide(data25DC['driver-CR2-1000p-dec_pckts-base'],nodes), label=f'driver CR2 1kp base', color='#2ca02c', linestyle='dashed')
#
#
# plt.title('decoded packet rate')
# plt.xlabel('nodes')
# plt.xscale('log')
# plt.ylabel('decoded packets rate')
# plt.xlim(1e2,1e4)
# plt.grid()
# plt.legend()
# plt.show()

# %% [markdown]
# ---
# # packet level collisions CR1 duty cycle 25%

# %%
data25DC_CR1 = pd.read_csv('NEWresults/data-25DC-CR1.csv', index_col=0, header=None).T
nodes = data25DC_CR1['nodes'].to_numpy()

data25DC_CR1_inf = pd.read_csv('NEWresults/data-25DC-CR1-inf.csv', index_col=0, header=None).T
nodesinf = data25DC_CR1_inf['nodesinf'].to_numpy()

lifan_CR1_infp_dec_pckts = np.subtract(nodesinf, data25DC_CR1_inf['lifan-CR1-infp-col_pckts'].to_numpy())
driver_CR1_infp_dec_pckts = np.subtract(nodesinf, data25DC_CR1_inf['driver-CR1-infp-col_pckts'].to_numpy())
lemgreen_CR1_infp_dec_pckts = np.subtract(nodesinf, np.multiply(nodesinf, data25DC_CR1_inf['lemgreen-CR1-infp-col_pckts'].to_numpy()))

plt.figure(figsize=(10,8))

#plt.plot(nodesinf, lifan_CR1_infp_dec_pckts, label=f'li-fan CR1 infp', color='#d62728')
plt.plot(nodesinf, lemgreen_CR1_infp_dec_pckts, label=f'lem-green CR1 infp', color='#d62728')
plt.plot(nodesinf, driver_CR1_infp_dec_pckts, label=f'driver CR1 infp', color='#d62728', linestyle='dashed')

#plt.plot(nodes, data25DC_CR1['lifan-CR1-100p-dec_pckts'], label=f'li-fan CR1 100p early d/d', color='#1f77b4', marker='$I$')
plt.plot(nodes, data25DC_CR1['lemgreen-CR1-100p-dec_pckts'], label=f'lem-green CR1 100p early d/d', color='#1f77b4', marker='$I$')
plt.plot(nodes, data25DC_CR1['driver-CR1-100p-dec_pckts'], label=f'driver CR1 100p early d/d', color='#1f77b4', marker='$I$', linestyle='dashed')

#plt.plot(nodes, data25DC_CR1['lifan-CR1-100p-dec_pckts-base'], label=f'li-fan CR1 100p base', color='#ff7f0e')
plt.plot(nodes, data25DC_CR1['lemgreen-CR1-100p-dec_pckts-base'], label=f'lem-green CR1 100p base', color='#ff7f0e')
plt.plot(nodes, data25DC_CR1['driver-CR1-100p-dec_pckts-base'], label=f'driver CR1 100p base', color='#ff7f0e', linestyle='dashed')

#plt.plot(nodes, data25DC_CR1['lifan-CR1-1000p-dec_pckts'], label=f'li-fan CR1 1000p early d/d', color='#9467bd', marker='$I$')
plt.plot(nodes, data25DC_CR1['lemgreen-CR1-1000p-dec_pckts'], label=f'lem-green CR1 1000p early d/d', color='#9467bd', marker='$I$')
plt.plot(nodes, data25DC_CR1['driver-CR1-1000p-dec_pckts'], label=f'driver CR1 1000p early d/d', color='#9467bd', marker='$I$', linestyle='dashed')

#plt.plot(nodes, data25DC_CR1['lifan-CR1-1000p-dec_pckts-base'], label=f'li-fan CR1 1000p base', color='#2ca02c')
plt.plot(nodes, data25DC_CR1['lemgreen-CR1-1000p-dec_pckts-base'], label=f'lem-green CR1 1000p base', color='#2ca02c')
plt.plot(nodes, data25DC_CR1['driver-CR1-1000p-dec_pckts-base'], label=f'driver CR1 1000p base', color='#2ca02c', linestyle='dashed')

plt.title('total decoded packets')
plt.xlabel('sent packets')
plt.xscale('log')
plt.ylabel('decoded packets')
plt.xlim(2e3,1e4)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,8))

#plt.plot(nodesinf, data25DC_CR1_inf['lifan-CR1-infp-col_pckts'], label=f'li-fan CR1 infp', color='#d62728')
#plt.plot(nodesinf, data25DC_CR1_inf['driver-CR1-infp-col_pckts'], label=f'driver CR1 infp', color='#d62728', linestyle='dashed')

plt.plot(nodes, data25DC_CR1['lifan-CR1-100p-col_pckts'], label=f'li-fan CR1 100p early d/d', color='#1f77b4')
plt.plot(nodes, data25DC_CR1['driver-CR1-100p-col_pckts'], label=f'driver CR1 100p early d/d', color='#1f77b4', linestyle='dashed')

plt.plot(nodes, data25DC_CR1['lifan-CR1-100p-col_pckts-base'], label=f'li-fan CR1 100p base', color='#ff7f0e')
plt.plot(nodes, data25DC_CR1['driver-CR1-100p-col_pckts-base'], label=f'driver CR1 100p base', color='#ff7f0e', linestyle='dashed')

plt.plot(nodes, data25DC_CR1['lifan-CR1-1000p-col_pckts'], label=f'li-fan CR1 1000p early d/d', color='#9467bd')
plt.plot(nodes, data25DC_CR1['driver-CR1-1000p-col_pckts'], label=f'driver CR1 1000p early d/d', color='#9467bd', linestyle='dashed')

plt.plot(nodes, data25DC_CR1['lifan-CR1-1000p-col_pckts-base'], label=f'li-fan CR1 1000p base', color='#2ca02c')
plt.plot(nodes, data25DC_CR1['driver-CR1-1000p-col_pckts-base'], label=f'driver CR1 1000p base', color='#2ca02c', linestyle='dashed')

plt.title('total colided packets')
plt.xlabel('nodes')
#plt.xscale('log')
plt.ylabel('colided packets')
#plt.xlim(1e2,1e4)
#plt.ylim(0,1e3)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ---
# # packet level collisions CR2 duty cycle 25% fhs length

# %%
data25DChops = pd.read_csv('NEWresults/data-25DC-CR2-hops.csv', index_col=0, header=None).T
nodes = data25DChops['nodes'].to_numpy()

plt.figure(figsize=(8,8))

plt.plot(nodes, data25DChops['lifan-CR2-100p-31hops-dec_pckts'], label=f'li-fan CR2 100p 31hops', color='#1f77b4')
plt.plot(nodes, data25DChops['driver-CR2-100p-31hops-dec_pckts'], label=f'driver CR2 100p 31hops', color='#1f77b4', linestyle='dashed')

plt.plot(nodes, data25DChops['lifan-CR2-100p-16hops-dec_pckts'], label=f'li-fan CR2 100p 16hops', color='#ff7f0e')
plt.plot(nodes, data25DChops['driver-CR2-100p-16hops-dec_pckts'], label=f'driver CR2 100p 16hops', color='#ff7f0e', linestyle='dashed')

plt.plot(nodes, data25DChops['lifan-CR2-100p-8hops-dec_pckts'], label=f'li-fan CR2 100p 8hops', color='#2ca02c')
plt.plot(nodes, data25DChops['driver-CR2-100p-8hops-dec_pckts'], label=f'driver CR2 100p 8hops', color='#2ca02c', linestyle='dashed')

plt.title('total decoded packets with early d/d and 25% duty cycle')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('decoded packets')
plt.xlim(1e2,1e4)
#plt.ylim(1e0,1e2)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ---
# # bytes

# %%
data25DC = pd.read_csv('NEWresults/data-25DC-CR2.csv', index_col=0, header=None).T
nodesCR2 = data25DC['nodes'].to_numpy()

data25DC_CR1 = pd.read_csv('NEWresults/data-25DC-CR1.csv', index_col=0, header=None).T
nodesCR1 = data25DC_CR1['nodes'].to_numpy()

bytesCR1 = nodesCR1 * 58
bytesCR2 = nodesCR2 * 121

plt.figure(figsize=(8,8))

plt.plot(bytesCR1, data25DC_CR1['lifan-CR1-100p-dec_bytes'] , label=f'li-fan CR1 100p', color='#ff7f0e')
plt.plot(bytesCR1, data25DC_CR1['driver-CR1-100p-dec_bytes'], label=f'driver CR1 100p', color='#ff7f0e', linestyle='dashed')

plt.plot(bytesCR2, data25DC['lifan-CR2-100p-dec_bytes'] , label=f'li-fan CR2 100p', color='#1f77b4')
plt.plot(bytesCR2, data25DC['driver-CR2-100p-dec_bytes'], label=f'driver CR2 100p', color='#1f77b4', linestyle='dashed')

plt.plot(bytesCR2, bytesCR2, label=f'ref', color='#d62728')

plt.title('total decoded data with early d/d')
plt.xlabel('sent data [bytes]')
plt.xscale('log')
plt.ylabel('decoded data [bytes]')
plt.xlim(1e4,1.5e6)
plt.ylim(0,5.5e4)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,8))

plt.plot(bytesCR1, data25DC_CR1['lifan-CR1-100p-dec_bytes-base'] , label=f'li-fan CR1 100p base', color='#9467bd')
plt.plot(bytesCR1, data25DC_CR1['driver-CR1-100p-dec_bytes-base'], label=f'driver CR1 100p base', color='#9467bd', linestyle='dashed')

plt.plot(bytesCR1, data25DC_CR1['lifan-CR1-100p-dec_bytes'] , label=f'li-fan CR1 100p early d/d', color='#ff7f0e', marker='$I$')
plt.plot(bytesCR1, data25DC_CR1['driver-CR1-100p-dec_bytes'], label=f'driver CR1 100p early d/d', color='#ff7f0e', marker='$I$', linestyle='dashed')

plt.plot(bytesCR2, data25DC['lifan-CR2-100p-dec_bytes-base'] , label=f'li-fan CR2 100p base', color='#2ca02c')
plt.plot(bytesCR2, data25DC['driver-CR2-100p-dec_bytes-base'], label=f'driver CR2 100p base', color='#2ca02c', linestyle='dashed')

plt.plot(bytesCR2, data25DC['lifan-CR2-100p-dec_bytes'] , label=f'li-fan CR2 100p early d/d', color='#1f77b4', marker='$I$')
plt.plot(bytesCR2, data25DC['driver-CR2-100p-dec_bytes'], label=f'driver CR2 100p early d/d', color='#1f77b4', marker='$I$', linestyle='dashed')

plt.title('total decoded data')
plt.xlabel('sent data [bytes]')
plt.xscale('log')
plt.ylabel('decoded data [bytes]')
#plt.xlim(1e4,1e6)
plt.grid()
plt.legend()
plt.show()

# %%
bytesCR1 = nodesCR1 * 58
bytesCR2 = nodesCR2 * 121

plt.figure(figsize=(8,8))

plt.plot(bytesCR1, data25DC_CR1['lifan-CR1-1000p-dec_bytes'] , label=f'li-fan CR1 1000p', color='#ff7f0e')
plt.plot(bytesCR1, data25DC_CR1['driver-CR1-1000p-dec_bytes'], label=f'driver CR1 1000p', color='#ff7f0e', linestyle='dashed')

plt.plot(bytesCR2, data25DC['lifan-CR2-1000p-dec_bytes'] , label=f'li-fan CR2 1000p', color='#1f77b4')
plt.plot(bytesCR2, data25DC['driver-CR2-1000p-dec_bytes'], label=f'driver CR2 1000p', color='#1f77b4', linestyle='dashed')

plt.plot(bytesCR2, bytesCR2, label=f'ref', color='#d62728')

plt.title('total decoded data with early d/d')
plt.xlabel('sent data [bytes]')
plt.xscale('log')
plt.ylabel('decoded data [bytes]')
plt.xlim(1e4,1.5e6)
plt.ylim(0,1.55e5)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ---
# # 5000 processors

# %%
data25DC = pd.read_csv('NEWresults/data-25DC-CR2.csv', index_col=0, header=None).T
nodes = data25DC['nodes'].to_numpy()

data5kp = pd.read_csv('NEWresults/data-5000p.csv', index_col=0, header=None).T
nodes5kp = data5kp['nodes'].to_numpy()

lifan_CR2_infp_dec_pckts = np.subtract(nodes, data25DC['lifan-CR2-infp-col_pckts'].to_numpy())
driver_CR2_infp_dec_pckts = np.subtract(nodes, data25DC['driver-CR2-infp-col_pckts'].to_numpy())

plt.figure(figsize=(8,8))

#plt.plot(nodes5kp, data5kp['lifan-CR2-5000p-dec_pckts'], label=f'li-fan CR2 5000p early d/d', marker='o', color='k')
plt.plot(nodes5kp, data5kp['lifan-CR2-5000p-dec_pckts-base'], label=f'li-fan CR2 5000p base', marker='o', color='#1f77b4')

plt.plot(nodes, lifan_CR2_infp_dec_pckts, label=f'li-fan CR2 infp', color='#d62728')
#plt.plot(nodes, data25DC['lifan-CR2-1000p-dec_pckts'], label=f'li-fan CR2 1000p early d/d', color='#9467bd', marker='$I$')
plt.plot(nodes, data25DC['lifan-CR2-1000p-dec_pckts-base'], label=f'li-fan CR2 1000p base', color='#2ca02c')

plt.title('total decoded packets')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('decoded packets')
plt.xlim(1e3,1e4)
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,8))

plt.plot(nodes5kp, data5kp['lifan-CR2-5000p-col_pckts'], label=f'li-fan CR2 5000p early d/d', marker='o', color='k')
plt.plot(nodes, data25DC['lifan-CR2-infp-col_pckts'], label=f'li-fan CR2 infp', color='#d62728')
plt.plot(nodes, data25DC['lifan-CR2-1000p-col_pckts'], label=f'li-fan CR2 1000p early d/d', color='#9467bd', marker='$I$')
plt.plot(nodes, data25DC['lifan-CR2-1000p-col_pckts-base'], label=f'li-fan CR2 1000p base', color='#2ca02c')

plt.title('total collided packets')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('collided packets')
plt.xlim(1e3,1e4)
plt.grid()
plt.legend()
plt.show()

# %%
for i in range(25,len(nodes)):
    print(f"nodes = {nodes[i]}\t\tinf = {round(lifan_CR2_infp_dec_pckts[i],3)}\t\t1000p = {data25DC['lifan-CR2-1000p-dec_pckts'].to_numpy()[i]}")
# Out:
# nodes = 339.0		inf = 319.2		1000p = 319.1
# nodes = 390.0		inf = 363.933		1000p = 364.7
# nodes = 449.0		inf = 417.4		1000p = 415.1
# nodes = 517.0		inf = 477.633		1000p = 484.1
# nodes = 596.0		inf = 541.5		1000p = 541.7
# nodes = 686.0		inf = 607.667		1000p = 613.7
# nodes = 790.0		inf = 690.167		1000p = 694.9
# nodes = 910.0		inf = 773.4		1000p = 781.2
# nodes = 1048.0		inf = 875.533		1000p = 878.2
# nodes = 1206.0		inf = 970.967		1000p = 973.0
# nodes = 1389.0		inf = 1061.567		1000p = 1064.5
# nodes = 1599.0		inf = 1139.967		1000p = 1147.5
# nodes = 1842.0		inf = 1187.967		1000p = 1210.9
# nodes = 2120.0		inf = 1182.167		1000p = 1212.5
# nodes = 2442.0		inf = 1119.4		1000p = 1155.0
# nodes = 2811.0		inf = 992.5		1000p = 1017.6
# nodes = 3237.0		inf = 825.1		1000p = 871.0
# nodes = 3727.0		inf = 635.5		1000p = 664.6
# nodes = 4291.0		inf = 462.4		1000p = 493.6
# nodes = 4941.0		inf = 319.767		1000p = 351.2
# nodes = 5689.0		inf = 226.033		1000p = 240.6
# ...

# %% [markdown]
# ---
# # fill between

# %%
nodes = [10, 11, 13, 15, 18, 20, 24, 28, 32, 37, 43, 50, 58, 68, 78, 91,
         106, 122, 142, 165, 191, 221, 257, 298, 345, 400, 464, 537, 623,
         722, 837, 970, 1125, 1304, 1511, 1752, 2030, 2353, 2728, 3162]

data10s = [[10, 10, 10, 10, 10, 10, 10, 10, 10, 10],
           [11, 11, 11, 11, 11, 11, 11, 11, 11, 11],
           [13, 11, 13, 13, 13, 13, 13, 13, 13, 13],
           [15, 15, 15, 15, 15, 15, 15, 15, 15, 15],
           [18, 18, 18, 18, 18, 18, 18, 18, 18, 16],
           [20, 20, 20, 20, 20, 20, 20, 20, 20, 20],
           [24, 24, 24, 24, 24, 24, 24, 24, 24, 24],
           [28, 28, 28, 28, 28, 28, 28, 28, 26, 28],
           [32, 32, 30, 32, 32, 32, 32, 32, 32, 32],
           [37, 35, 37, 37, 35, 37, 37, 37, 37, 37],
           [43, 43, 43, 43, 43, 43, 43, 43, 43, 43],
           [50, 50, 50, 48, 50, 50, 50, 50, 50, 50],
           [58, 58, 58, 58, 58, 56, 56, 58, 58, 58],
           [66, 68, 64, 68, 68, 68, 68, 68, 68, 68],
           [78, 78, 78, 76, 76, 74, 78, 76, 74, 76],
           [91, 89, 89, 91, 89, 85, 89, 89, 91, 85],
           [104, 104, 104, 102, 106, 100, 106, 104, 102, 104],
           [122, 120, 120, 122, 118, 118, 116, 120, 122, 116],
           [136, 138, 138, 142, 142, 138, 136, 140, 140, 136],
           [163, 163, 161, 157, 160, 163, 163, 161, 162, 165],
           [185, 185, 183, 189, 187, 187, 183, 181, 185, 191],
           [217, 217, 221, 211, 213, 207, 213, 215, 213, 207],
           [249, 247, 247, 249, 243, 257, 251, 247, 251, 251],
           [292, 286, 282, 286, 294, 286, 286, 288, 282, 296],
           [332, 318, 324, 323, 329, 327, 321, 316, 333, 320],
           [366, 387, 365, 374, 366, 373, 380, 366, 375, 367],
           [400, 386, 408, 380, 406, 388, 389, 400, 401, 383],
           [402, 403, 403, 405, 399, 414, 403, 393, 413, 405],
           [421, 411, 407, 408, 417, 408, 415, 412, 404, 404],
           [411, 418, 402, 410, 408, 400, 413, 399, 412, 390],
           [412, 407, 406, 394, 393, 402, 399, 406, 402, 390],
           [393, 397, 397, 388, 396, 388, 398, 393, 382, 403],
           [385, 377, 379, 388, 391, 389, 378, 376, 392, 382],
           [360, 365, 383, 370, 364, 373, 365, 384, 363, 370],
           [353, 358, 354, 354, 363, 345, 347, 352, 349, 358],
           [339, 324, 324, 320, 324, 346, 336, 341, 315, 337],
           [295, 302, 299, 303, 294, 296, 289, 319, 282, 295],
           [269, 244, 265, 262, 241, 245, 263, 266, 272, 260],
           [205, 213, 200, 214, 227, 220, 213, 218, 222, 199],
           [168, 160, 163, 172, 174, 167, 151, 167, 151, 176]]

data10s_min = [min(x) for x in data10s]
data10s_max = [max(x) for x in data10s]
data10s_std = [np.std(x) for x in data10s]
data10s_avg = [np.mean(x) for x in data10s]


data30s = [[10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10],
           [11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11],
           [13, 13, 13, 13, 13, 13, 11, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13, 13],
           [15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15],
           [18, 16, 18, 16, 18, 16, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18],
           [20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20],
           [24, 22, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24],
           [28, 28, 28, 26, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28],
           [32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 30, 32, 32, 32, 32],
           [37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 35, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 37, 35, 37, 37, 37, 37],
           [43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 43, 39, 43, 43, 43, 43, 39, 43, 43, 43],
           [50, 50, 50, 48, 50, 50, 50, 50, 50, 48, 50, 50, 48, 48, 50, 48, 50, 50, 50, 50, 50, 50, 48, 48, 50, 50, 50, 50, 50, 50],
           [58, 58, 58, 58, 58, 58, 58, 58, 56, 58, 58, 58, 58, 58, 54, 58, 58, 58, 56, 58, 58, 58, 58, 58, 54, 58, 58, 54, 58, 58],
           [68, 66, 68, 66, 68, 66, 68, 68, 64, 66, 68, 66, 68, 68, 66, 68, 68, 68, 68, 64, 68, 68, 68, 68, 68, 66, 68, 68, 68, 68],
           [78, 78, 78, 78, 76, 78, 78, 78, 78, 78, 78, 78, 78, 78, 76, 74, 78, 78, 76, 78, 78, 76, 78, 76, 76, 78, 76, 78, 78, 78],
           [91, 87, 89, 89, 91, 89, 91, 89, 89, 89, 87, 91, 91, 91, 87, 91, 89, 91, 91, 91, 89, 91, 91, 91, 91, 87, 89, 91, 87, 91],
           [106, 106, 106, 106, 106, 104, 106, 106, 102, 98, 98, 104, 104, 106, 102, 102, 104, 104, 102, 102, 104, 102, 104, 102, 104, 106, 106, 104, 106, 104],
           [120, 120, 120, 122, 122, 118, 118, 118, 120, 120, 122, 122, 118, 116, 122, 118, 118, 120, 120, 118, 116, 120, 122, 120, 120, 118, 118, 122, 122, 122],
           [138, 136, 140, 136, 142, 138, 136, 140, 138, 140, 138, 138, 136, 138, 142, 133, 140, 138, 142, 142, 138, 138, 140, 136, 136, 138, 136, 138, 138, 142],
           [159, 161, 159, 163, 161, 163, 154, 161, 165, 157, 163, 161, 159, 161, 157, 163, 159, 161, 163, 163, 163, 157, 163, 163, 165, 163, 161, 157, 157, 161],
           [185, 185, 189, 185, 183, 181, 181, 179, 183, 187, 183, 187, 185, 191, 179, 189, 187, 187, 185, 185, 189, 191, 185, 189, 185, 183, 187, 191, 189, 183],
           [209, 217, 215, 211, 213, 215, 213, 217, 209, 211, 207, 215, 217, 211, 211, 215, 209, 213, 213, 209, 214, 213, 213, 219, 211, 207, 215, 211, 213, 211],
           [247, 242, 251, 253, 241, 245, 248, 243, 243, 245, 244, 249, 247, 248, 253, 247, 247, 243, 253, 245, 245, 243, 251, 243, 245, 235, 251, 253, 243, 249],
           [277, 277, 278, 276, 282, 279, 284, 284, 278, 284, 280, 282, 289, 289, 294, 285, 282, 288, 286, 286, 290, 286, 290, 282, 281, 286, 284, 276, 286, 278],
           [314, 329, 323, 322, 331, 325, 327, 323, 327, 337, 320, 325, 327, 317, 329, 330, 324, 331, 335, 322, 316, 325, 333, 331, 322, 322, 319, 327, 336, 329],
           [369, 367, 388, 365, 362, 361, 374, 348, 372, 358, 375, 363, 365, 351, 361, 359, 370, 367, 354, 375, 347, 373, 367, 364, 369, 370, 370, 379, 364, 368],
           [404, 404, 396, 402, 399, 402, 392, 402, 389, 387, 402, 399, 407, 402, 392, 396, 396, 400, 403, 391, 395, 389, 391, 395, 400, 396, 388, 405, 392, 392],
           [402, 406, 393, 407, 406, 406, 394, 399, 410, 399, 402, 405, 411, 408, 399, 406, 409, 396, 398, 403, 406, 413, 397, 401, 402, 405, 421, 410, 407, 405],
           [409, 407, 407, 399, 412, 408, 396, 407, 409, 409, 402, 415, 405, 405, 412, 405, 405, 411, 404, 404, 400, 399, 406, 390, 416, 420, 410, 416, 400, 409],
           [416, 410, 398, 396, 403, 407, 410, 411, 402, 402, 402, 405, 397, 399, 406, 405, 408, 404, 403, 411, 406, 416, 404, 410, 407, 406, 407, 402, 405, 400],
           [402, 403, 404, 405, 402, 405, 406, 397, 408, 402, 404, 402, 406, 394, 393, 402, 392, 396, 401, 398, 393, 395, 404, 401, 393, 404, 401, 405, 391, 398],
           [386, 396, 398, 392, 398, 395, 383, 395, 381, 390, 379, 395, 398, 400, 393, 383, 391, 394, 397, 388, 386, 399, 391, 395, 396, 401, 386, 392, 390, 394],
           [390, 379, 383, 381, 372, 384, 387, 387, 386, 378, 387, 373, 385, 370, 380, 376, 383, 377, 384, 388, 385, 391, 390, 384, 390, 391, 379, 381, 374, 381],
           [376, 377, 384, 370, 359, 385, 367, 378, 365, 373, 362, 376, 360, 369, 372, 380, 373, 374, 356, 372, 372, 377, 376, 373, 375, 361, 373, 380, 376, 363],
           [354, 341, 358, 363, 361, 348, 369, 350, 354, 357, 351, 346, 355, 357, 360, 352, 360, 358, 349, 351, 350, 343, 354, 355, 348, 344, 349, 352, 345, 361],
           [330, 330, 314, 318, 320, 324, 323, 326, 321, 329, 324, 320, 321, 336, 327, 330, 318, 336, 346, 322, 325, 326, 350, 320, 321, 328, 342, 327, 324, 332],
           [293, 295, 295, 291, 305, 309, 291, 290, 307, 283, 298, 300, 295, 304, 305, 300, 289, 303, 299, 309, 297, 297, 304, 281, 284, 303, 301, 308, 291, 290],
           [255, 269, 267, 255, 249, 252, 252, 258, 241, 276, 276, 247, 265, 255, 272, 257, 267, 254, 252, 257, 249, 258, 246, 250, 258, 248, 267, 249, 254, 281],
           [213, 213, 226, 205, 216, 223, 231, 202, 214, 220, 197, 219, 216, 217, 209, 214, 231, 204, 195, 226, 195, 221, 202, 202, 212, 214, 202, 233, 220, 221],
           [166, 168, 175, 176, 170, 179, 180, 165, 162, 169, 177, 165, 158, 165, 173, 157, 162, 168, 190, 199, 177, 170, 161, 155, 166, 161, 169, 157, 161, 167]]

data30s_min = [min(x) for x in data30s]
data30s_max = [max(x) for x in data30s]
data30s_std = [np.std(x) for x in data30s]
data30s_avg = [np.mean(x) for x in data30s]

# %%
plt.figure(figsize=(8,8))

plt.plot(nodes, data10s_avg, label='10 samples', color='#d62728')
plt.plot(nodes, data30s_avg, label='30 samples',color='#1f77b4')

plt.fill_between(nodes, data10s_min, data10s_max, facecolor='pink')
plt.fill_between(nodes, data30s_min, data30s_max, facecolor='skyblue')

plt.title('total decoded packets')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('decoded packets')
plt.grid()
plt.xlim(1e2,3.5e3)
plt.ylim(1e2,4.3e2)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,8))

plt.plot(nodes, data10s_avg, label='10 samples', color='#d62728')
plt.plot(nodes, data30s_avg, label='30 samples',color='#1f77b4')

plt.fill_between(nodes, np.subtract(data10s_avg, data10s_std), np.add(data10s_avg, data10s_std), facecolor='pink')
plt.fill_between(nodes, np.subtract(data30s_avg, data30s_std), np.add(data30s_avg, data30s_std), facecolor='skyblue')

plt.title('total decoded packets')
plt.xlabel('nodes')
plt.xscale('log')
plt.ylabel('decoded packets')
plt.grid()
plt.xlim(1e2,3.5e3)
plt.ylim(1e2,4.3e2)
plt.legend()
plt.show()
